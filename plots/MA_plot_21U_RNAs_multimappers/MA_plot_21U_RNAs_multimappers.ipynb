# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /tungstenfs/nobackup/ggrossha/gypafoiv/miniconda3/envs/python_3.7/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Global options

sns.set_style("white")
sns.set(font_scale=2, style="ticks")

height=15
aspect=1
x_jitter=0
y_jitter=0

# xlim=(0,10)
ylim=(-3, 3)
alpha=1
marker='.'
s=1
legend=True
legend_out=False
linewidth=0
x_jitter=0
y_jitter=0
plt.rcParams["figure.figsize"] = (20,20)

# %%
WT__Dpf_3_null_21U_RNA = pd.read_csv("../../01_small_RNA_seq_15_C/results/filter_sequences/DE_sequences_1_alignment_per_read__21T__WT__Dpf_3_null/DE_edgeR/final_table.tsv",
                                     header=0,
                                     sep="\t")

# %%
WT__Dpf_3_null_21U_RNA["Significant"] = "No"
WT__Dpf_3_null_21U_RNA.loc[(WT__Dpf_3_null_21U_RNA["FDR"]<0.05) & ((WT__Dpf_3_null_21U_RNA["logFC"])<0), "Significant"] = "FDR<0.05\nlogFC<0"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT__Dpf_3_null_21U_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05\nlogFC<0"],
                      palette=["gray", "black"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)
sns_plot = plt.gca()
sns_plot.set_title(f"Dpf-3 null over WT - 21U RNA")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)
sns_plot.set(ylim=ylim)


plt.savefig("Dpf-3_null_over_WT_21U_RNA.pdf")

WT__Dpf_3_null_21U_RNA["Significant"].value_counts()
# Out:
# No    292
# Name: Significant, dtype: int64

# %%
WT__Dpf_3_S784A_21U_RNA = pd.read_csv("../../01_small_RNA_seq_15_C/results/filter_sequences/DE_sequences_1_alignment_per_read__21T__WT__Dpf_3_S784A/DE_edgeR/final_table.tsv",
                                     header=0,
                                     sep="\t")

# %%
WT__Dpf_3_S784A_21U_RNA["Significant"] = "No"
WT__Dpf_3_S784A_21U_RNA.loc[(WT__Dpf_3_S784A_21U_RNA["FDR"]<0.05) & (WT__Dpf_3_S784A_21U_RNA["logFC"]<0), "Significant"] = "FDR<0.05\nlogFC<0"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT__Dpf_3_S784A_21U_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05\nlogFC<0"],
                      palette=["gray", "black"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)
sns_plot = plt.gca()
sns_plot.set_title(f"Dpf-3 S784A over WT - 21U RNA")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)
sns_plot.set(ylim=ylim)


plt.savefig("Dpf-3_Dpf_3_over_WT_21U_RNA.pdf")

print(WT__Dpf_3_S784A_21U_RNA["Significant"].value_counts())
# Out:
# No                   164
# FDR<0.05\nlogFC<0     51
# Name: Significant, dtype: int64

# %%
WT__mut_2_21U_RNA = pd.read_csv("../../01_small_RNA_seq_15_C/results/filter_sequences/DE_sequences_1_alignment_per_read__21T__WT__mut_2/DE_edgeR/final_table.tsv",
                                  header=0,
                                  sep="\t")

# %%
WT__mut_2_21U_RNA["Significant"] = "No"
WT__mut_2_21U_RNA.loc[(WT__mut_2_21U_RNA["FDR"]<0.05) & (WT__mut_2_21U_RNA["logFC"]<0), "Significant"] = "FDR<0.05\nlogFC<0"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT__mut_2_21U_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05\nlogFC<0"],
                      palette=["gray", "black"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)

sns_plot = plt.gca()
sns_plot.set_title(f"mut-2 over WT - 21U RNA")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)
sns_plot.set(ylim=ylim)


plt.savefig("mut-2_over_WT_21U_RNA.pdf")

WT__mut_2_21U_RNA["Significant"].value_counts()
# Out:
# No                   218
# FDR<0.05\nlogFC<0     10
# Name: Significant, dtype: int64

# %%
WT__mut_7_21U_RNA = pd.read_csv("../../01_small_RNA_seq_15_C/results/filter_sequences/DE_sequences_1_alignment_per_read__21T__WT__mut_7/DE_edgeR/final_table.tsv",
                                  header=0,
                                  sep="\t")

# %%
WT__mut_7_21U_RNA["Significant"] = "No"
WT__mut_7_21U_RNA.loc[(WT__mut_7_21U_RNA["FDR"]<0.05) & (WT__mut_7_21U_RNA["logFC"]<0), "Significant"] = "FDR<0.05\nlogFC<0"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT__mut_7_21U_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05\nlogFC<0"],
                      palette=["gray", "black"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)

sns_plot = plt.gca()
sns_plot.set_title(f"mut-7 over WT - 21U RNA")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)
sns_plot.set(ylim=ylim)


plt.savefig("mut-7_over_WT_21U_RNA.pdf")

WT__mut_7_21U_RNA["Significant"].value_counts()
# Out:
# No                   337
# FDR<0.05\nlogFC<0     15
# Name: Significant, dtype: int64
