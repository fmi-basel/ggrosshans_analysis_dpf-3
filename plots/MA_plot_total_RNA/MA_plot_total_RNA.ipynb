# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Global options

sns.set_style("white")
sns.set(font_scale=2, style="ticks")

height=15
aspect=1
x_jitter=0
y_jitter=0

# xlim=(0,10)
ylim=(-10, 10)
alpha=1
marker='.'
s=1
legend=True
legend_out=False
linewidth=0
x_jitter=0
y_jitter=0
plt.rcParams["figure.figsize"] = (20,20)

# %%
WT__Dpf_3_null_total_RNA = pd.read_csv("../../02_total_RNAseq_15_C/results/filter/DE_htseq_count_alignment_unique_mappers__reverse__WT__Dpf_3_null/DE_edgeR/final_table_with_gene_info.tsv",
                                       header=0,
                                       sep="\t")

# %%
WT__Dpf_3_null_total_RNA["Significant"] = "No"
WT__Dpf_3_null_total_RNA.loc[WT__Dpf_3_null_total_RNA["FDR"]<0.05, "Significant"] = "FDR<0.05"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT__Dpf_3_null_total_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05"],
                      palette=["black", "red"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)
sns_plot = plt.gca()
sns_plot.set_title(f"MA plot total RNA-seq Dpf-3 null over WT")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)

plt.savefig("Dpf-3_null_over_WT.pdf")

WT__Dpf_3_null_total_RNA["Significant"].value_counts()
# Out:
# No          13915
# FDR<0.05     3234
# Name: Significant, dtype: int64

# %%
WT__mut_2_total_RNA = pd.read_csv("../../02_total_RNAseq_15_C/results/filter/DE_htseq_count_alignment_unique_mappers__reverse__WT__mut_2/DE_edgeR/final_table_with_gene_info.tsv",
                                       header=0,
                                       sep="\t")

# %%
WT__mut_2_total_RNA["Significant"] = "No"
WT__mut_2_total_RNA.loc[WT__mut_2_total_RNA["FDR"]<0.05, "Significant"] = "FDR<0.05"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT__mut_2_total_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05"],
                      palette=["black", "red"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)

sns_plot = plt.gca()
sns_plot.set_title(f"MA plot total RNA-seq mut-2 over WT")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)

plt.savefig("mut-2_over_WT.pdf")

WT__Dpf_3_null_total_RNA["Significant"].value_counts()
# Out:
# No          13915
# FDR<0.05     3234
# Name: Significant, dtype: int64

# %%
WT_last__mut_2_total_RNA = pd.read_csv("../../02_total_RNAseq_15_C/results/filter/DE_htseq_count_alignment_unique_mappers__reverse__WT_last__mut_2/DE_edgeR/final_table_with_gene_info.tsv",
                                       header=0,
                                       sep="\t")

# %%
WT_last__mut_2_total_RNA["Significant"] = "No"
WT_last__mut_2_total_RNA.loc[WT_last__mut_2_total_RNA["FDR"]<0.05, "Significant"] = "FDR<0.05"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT_last__mut_2_total_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05"],
                      palette=["black", "red"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)

sns_plot = plt.gca()
sns_plot.set_title(f"MA plot total RNA-seq mut-2 over WT last")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)

plt.savefig("mut-2_over_WT_last.pdf")

WT__Dpf_3_null_total_RNA["Significant"].value_counts()
# Out:
# No          13915
# FDR<0.05     3234
# Name: Significant, dtype: int64

# %%
WT__mut_7_total_RNA = pd.read_csv("../../02_total_RNAseq_15_C/results/filter/DE_htseq_count_alignment_unique_mappers__reverse__WT__mut_7/DE_edgeR/final_table_with_gene_info.tsv",
                                       header=0,
                                       sep="\t")

# %%
WT__mut_7_total_RNA["Significant"] = "No"
WT__mut_7_total_RNA.loc[WT__mut_7_total_RNA["FDR"]<0.05, "Significant"] = "FDR<0.05"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT__mut_7_total_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05"],
                      palette=["black", "red"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)

sns_plot = plt.gca()
sns_plot.set_title(f"MA plot total RNA-seq mut-7 over WT")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)

plt.savefig("mut-7_over_WT.pdf")

WT__Dpf_3_null_total_RNA["Significant"].value_counts()
# Out:
# No          13915
# FDR<0.05     3234
# Name: Significant, dtype: int64

# %%
WT_last__mut_7_total_RNA = pd.read_csv("../../02_total_RNAseq_15_C/results/filter/DE_htseq_count_alignment_unique_mappers__reverse__WT_last__mut_7/DE_edgeR/final_table_with_gene_info.tsv",
                                       header=0,
                                       sep="\t")

# %%
WT_last__mut_7_total_RNA["Significant"] = "No"
WT_last__mut_7_total_RNA.loc[WT_last__mut_7_total_RNA["FDR"]<0.05, "Significant"] = "FDR<0.05"

sns_plot = sns.lmplot(x=f"logCPM",
                      y=f"logFC",
                      data=WT_last__mut_7_total_RNA,
                      fit_reg=False,
                      hue=f"Significant",
                      hue_order=["No", "FDR<0.05"],
                      palette=["black", "red"],
                      scatter_kws={'alpha':alpha},
                      height=height,
                      aspect=aspect,
                      x_jitter=x_jitter,
                      y_jitter=y_jitter,
                      markers=marker,
                      legend=legend,
                      legend_out = legend_out)

sns_plot = plt.gca()
sns_plot.set_title(f"MA plot total RNA-seq mut-7 over WT last")
sns_plot.spines['right'].set_visible(True)
sns_plot.spines['top'].set_visible(True)

plt.savefig("mut-7_over_WT_last.pdf")

WT__Dpf_3_null_total_RNA["Significant"].value_counts()
# Out:
# No          13915
# FDR<0.05     3234
# Name: Significant, dtype: int64
