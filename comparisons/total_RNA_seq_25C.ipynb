# %%
from IPython.display import Image
import pandas as pd

# %%
# !ls ../total_RNA_seq_25_C/results/filter/DE_feature_counts__WT__dpf_3_null/DE_edgeR/final_table_FDR_low_with_gene_info.tsv
# Out:
# ../total_RNA_seq_25_C/results/filter/DE_feature_counts__WT__dpf_3_null/DE_edgeR/final_table_FDR_low_with_gene_info.tsv

# %% [markdown]
# # dpf_3_null over WT

# %%
Image("../total_RNA_seq_25_C/results/filter/DE_feature_counts__WT__dpf_3_null/DE_edgeR/ma_plot.png")

# %%
Image("../total_RNA_seq_25_C/results/filter/DE_feature_counts_repeat_name_level__WT__dpf_3_null/DE_edgeR/ma_plot.png")

# %% [markdown]
# # dpf_3_S784A over WT

# %%
Image("../total_RNA_seq_25_C/results/filter/DE_feature_counts__WT__dpf_3_S784A/DE_edgeR/ma_plot.png")

# %%
Image("../total_RNA_seq_25_C/results/filter/DE_feature_counts_repeat_name_level__WT__dpf_3_S784A/DE_edgeR/ma_plot.png")

# %% [markdown]
# # drh_3 over WT

# %%
Image("../total_RNA_seq_25_C/results/filter/DE_feature_counts__WT__drh_3_mutant/DE_edgeR/ma_plot.png")

# %%
Image("../total_RNA_seq_25_C/results/filter/DE_feature_counts_repeat_name_level__WT__drh_3_mutant/DE_edgeR/ma_plot.png")

# %%
df = pd.read_csv("../total_RNA_seq_25_C/results/filter/DE_feature_counts__WT__dpf_3_null/DE_edgeR/final_table_FDR_low_with_gene_info.tsv", header=0, sep="\t")

# %%
df
# Out:
#                        id     logFC    logCPM          LR        PValue  \
# 0     I:5980182-5981873:- -1.171485  3.919855   15.526228  8.136842e-05
# 1    II:2157812-2160282:-  2.846935  2.109730   19.110924  1.233369e-05
# 2    II:2161923-2163814:-  1.792929  1.544314   15.496647  8.265173e-05
# 3      IV:913372-921243:+  2.452306  4.341244   20.839684  4.993747e-06
# 4   V:17137383-17141676:- -1.358957  2.348251   15.667378  7.551547e-05
# 5   V:18436471-18442343:+  2.068476  3.167623   18.187687  2.001688e-05
# 6   V:18443955-18455084:+  2.525438  2.869328   15.989713  6.368759e-05
# 7     V:5180270-5183550:+  2.141129  2.501263   28.931485  7.498411e-08
# 8     V:5183803-5185271:+  2.828744  2.738711   31.358752  2.144896e-08
# 9     V:5185266-5189607:+  2.556938  3.968135   23.617393  1.175205e-06
# 10    V:5190000-5190664:+  2.433387  1.323006   20.711778  5.338661e-06
# 11    V:5200855-5201506:+  4.753440 -0.034081   48.815091  2.812673e-12
# ...
