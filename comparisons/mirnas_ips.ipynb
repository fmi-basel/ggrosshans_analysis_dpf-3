# %%
import pandas as pd
from IPython.display import Image

# %%
# !ls -d ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNA*
# Out:
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__IP_WAGO-1_P3G__IP_WAGO-1
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__IP_WAGO-1_dpf-3_null__IP_WAGO-1
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__IP_WAGO-3_dpf-3_null__IP_WAGO-3
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__IP_WAGO-4_dpf-3_null__IP_WAGO-4
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-1_P3G__IP_WAGO-1_P3G
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-1__IP_WAGO-1
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-1_dpf-3_null__IP_WAGO-1_dpf-3_null
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-3__IP_WAGO-3
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-3_dpf-3_null__IP_WAGO-3_dpf-3_null
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-4__IP_WAGO-4
# ../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-4_dpf-3_null__IP_WAGO-4_dpf-3_null

# %% [markdown]
# # IP WAGO 1 vs Input WAGO 1

# %%
Image("../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__Input_WAGO-1__IP_WAGO-1/DE_edgeR/ma_plot.png")

# %% [markdown]
# # IP WAGO 1 vs IP WAGO 1 dpf-3 null

# %%
Image("../03_WAGO_IPs/results/filter/DE_htseq_count_miRNAs__IP_WAGO-1_dpf-3_null__IP_WAGO-1/DE_edgeR/ma_plot.png")
